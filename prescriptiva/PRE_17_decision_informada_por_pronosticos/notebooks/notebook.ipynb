# %%
# Problema: Decidir cuánto inventario pedir cuando el pronóstico de demanda tiene varios escenarios plausibles.

from pathlib import Path
import sys
import pandas as pd
root=Path.cwd().parent
sys.path.insert(0,str(root/'src'))
from main import evaluate
result=evaluate(pd.read_csv(root/'data'/'order_options.csv'),pd.read_csv(root/'data'/'forecast_scenarios.csv'))
result.to_csv(root/'submission'/'order_comparison.csv',index=False)
result
