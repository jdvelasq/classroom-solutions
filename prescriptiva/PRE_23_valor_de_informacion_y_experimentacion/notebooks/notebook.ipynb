# %%
# Problema: Decidir si conviene intervenir ahora o medir antes cuando el resultado depende de la demanda futura.

from pathlib import Path
import sys,pandas as pd
root=Path.cwd().parent
sys.path.insert(0,str(root/'src'))
from main import evaluate
result=evaluate(pd.read_csv(root/'data'/'decision_scenarios.csv'))
result.to_csv(root/'submission'/'information_value.csv',index=False)
result
