# %%
# Problema: Documentar una recomendación, sus supuestos y el gatillo que obliga a revisarla.

from pathlib import Path
import subprocess
root=Path.cwd().parent
subprocess.run(['python3',str(root/'src'/'main.py')],check=True)
