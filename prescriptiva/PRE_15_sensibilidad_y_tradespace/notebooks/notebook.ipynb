# %%
# Problema: Determinar qué promesa de entrega crea valor y bajo qué cambios de retención se invierte la recomendación.

from pathlib import Path
import sys
import pandas as pd
root = Path.cwd().parent
sys.path.insert(0, str(root / 'src'))
from main import evaluate
options = pd.read_csv(root / 'data' / 'service_options.csv')
result = evaluate(options)
result.to_csv(root / 'submission' / 'tradespace.csv', index=False)
result
