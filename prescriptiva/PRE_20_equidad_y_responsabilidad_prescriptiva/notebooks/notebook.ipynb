# %%
# Problema: Auditar si una política de contacto distribuye de manera desigual sus beneficios y definir cuándo debe revisarse.

from pathlib import Path
import sys
import pandas as pd
root=Path.cwd().parent
sys.path.insert(0,str(root/'src'))
from main import audit
result=audit(pd.read_csv(root/'data'/'policy_impacts.csv'))
result.to_csv(root/'submission'/'equity_audit.csv',index=False)
result
